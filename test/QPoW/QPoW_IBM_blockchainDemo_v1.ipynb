# %% [markdown]
# # Quantum Proof of Work: q-circuit with parametric quantum gates
# #### code developed by Mikhail Shalaginov (mys@mit.edu) and Michael Dubrovsky (mike@powx.org)

# %% [markdown]
# Proof of work (PoW) is the mechanism allowing formation of decentralized cryptocurrency blockchains (e.g. Bitcoin, Etherium, etc). Here we introduce a quantum computing part to a traditional mining cycle in a similar way as it has been proposed earlier for <a href="https://assets.pubpub.org/xi9h9rps/01581688887859.pdf">optical PoW</a>. The QPoW cycle is illustrated on a schematic below.
#
# The input ('text') is a concatenated string containing: nonce, transaction data and a hash-string from a previous run. Nonce is an integer starting from 0 value and incrementing by 1 with each cycle, transaction data is a ledger entry, e.g. <font color='green'>'Schroedinger paid Einstein 1 qBTC'</font>. By SHA3 algorithm the 'text' (e.g. <font color='green'>'4Schroedinger paid Einstein 1 qBTC04ca1a782621a440d03b5d87ecff8b68e2cc6124f57957b49a76bca91dede3a81'</font>) is transformed into a 256-bit hash-string (<font color='green'>'e1e5575da3a9e86da135552facddcc1ff44dd26502d0bc2b22961383f8b187ca'</font>) that is pushed through the QPoW stages. After all of the computations, we have a 256-bit hash-string as an output(<font color='green'>'f307b3db12a649563831e3e1328c3c7a5b15ee541afaab563727cb992cf9d1ca'</font>). If the output satisfies the conditions set by the task difficulty, i.e. the output string has a certain number of zeros, then the block is reported to be successfully found. Otherwise, the output hash feeds back into the input 'text' and the nonce is increased by 1. When the block is finally found, it goes through a verification test performed by a quantum simulator ran on a classical computer.
#
# In this demo we demonstrate the construction of a block-chain composed of several elements (5 in this example) by computing the quantum algorithm on a 4-qubit IBM Q node (<a href="https://quantum-computing.ibm.com/">ibmq_lima</a>).

# %% [markdown]
# <img src="images/QPoW_schematic2.png" alt="Note: In order for images to show up in this jupyter notebook you need to select File => Trusted Notebook" width="1200 px" align="center">

# %%
# import modules for SHA
import sys
import hashlib
import numpy as np
import random

if sys.version_info < (3, 6):
	import sha3

# import modules for Qiskit
import qiskit
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit import BasicAer, Aer, IBMQ, execute, schedule
from qiskit.compiler import transpile
from qiskit.tools.visualization import plot_histogram
from qiskit.transpiler import PassManager
from qiskit.tools.monitor import job_monitor
from qiskit.providers.aer import AerSimulator
# from azure.quantum.qiskit import AzureQuantumProvider

# import other useful packages 
from numpy import pi
from datetime import date
import time

# settings for IBM Q backends
# TOKEN = ''
# IBMQ.save_account(TOKEN)
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
qpu_name = 'ibmq_lima'
simulator_name = 'qasm_simulator'
qpu_backend = provider.get_backend(qpu_name)

# create data-storage files
today = date.today()
date = today.strftime("%Y%m%d")
filepath = '' #specify data storage folder
filename_results = filepath + date + '_results_IBM_ch7_sim.txt'
filename_log = filepath + date + '_log_IBM5_ch7_sim.txt'
filename_bc = filepath + date + '_block_chain7_sim.txt'

# input parameters
previous_hash = '' #empty hash
block_number = 0
numberOfBlocks = 5
errors = 0 #number of 'False' nonces
difficulty = 1 #number of prefix zeros (hash-problem difficulty)
transactions ='Schroedinger paid Einstein 1 qBTC'
QC_switch = 0 #0 - simulator, 1 - real QC
MAX_NONCE = 100000000000

# loop for building a blockchain
counter = 0
while counter < numberOfBlocks:

    with open(filename_log, 'a') as o:
        o.write('mining started \n')
        o.write('difficulty:'+ str(difficulty)+ '\n')
        o.write('previous_hash:' + str(previous_hash)+ '\n')
        o.write('transactions:' + str(transactions) +'\n')
        o.write('block_number:' + str(block_number) + '\n')
        o.write('QC_switch:' + str(QC_switch) + '\n\n')

    with open(filename_results, 'a') as o:
        o.write('mining started \n')
        o.write('difficulty:'+ str(difficulty)+ '\n')
        o.write('previous_hash:' + str(previous_hash)+ '\n')
        o.write('transactions:' + str(transactions) +'\n')
        o.write('block_number:' + str(block_number) + '\n')
        o.write('QC_switch:' + str(QC_switch) + '\n\n')

    if QC_switch == 1:
        with open(filename_results, 'a') as o:
            o.write('IBM node:'+ qpu_name)
    else:
        with open(filename_results, 'a') as o:
            o.write('IBM node:'+ simulator_name)

### Mining functions

    # QPoW cycle: function takes the input text (block number, nonce,...) and pushes it through once 
    def qPoW(text, QC_switch, nonce):

        hashIn = hashlib.sha3_256(text.encode("ascii")).hexdigest() # hashing the 'text' input
        #string-type output
        
        print ('hashIn-hex:', hashIn, 'length:', len(hashIn))
        with open(filename_log, 'a') as o:
            o.write('hashIn-hex:' + str(hashIn)+ '\n')

        # convert hashIn(hex) to hashIn_bin(binary)
        scale = 16 #hex base
        hashIn_bin = bin(int(hashIn, scale))[2:].zfill(len(hashIn)*4)
        print ('hashIn-binary:', str(hashIn_bin), 'length:', len(hashIn_bin))
        with open(filename_log, 'a') as o:
            o.write('hashIn-binary:' + str(hashIn_bin)+ '\n')

        #switch to enable quantum simulator or quantum computer
        if QC_switch == 0:
            [qstate_bin, comp_time] = sim_quantum_operation(hashIn_bin, nonce)
        if QC_switch == 1: 
            [qstate_bin, comp_time] = exp_quantum_operation(hashIn_bin, nonce, qpu_backend) #qstate is a 256 binary number

        print('qblock-output:', str(qstate_bin), 'length:', len(qstate_bin))

        xor_bin = xor(str(hashIn_bin), str(qstate_bin), 256)
        hashOut = hashlib.sha3_256(xor_bin.encode("ascii")).hexdigest()

        print('XOR:', str(xor_bin), 'length:', len(xor_bin))
        with open(filename_log, 'a') as o:
            o.write('XOR:'+ str(xor_bin) + 'length:'+ str(len(xor_bin)) + '\n')

        print('hashOut-hex:', str(hashOut), 'length:', len(hashOut), '\n\n')

        return [hashOut, comp_time]

    #mining based on multiple qPoW cycles, the function runs untill it finds the nonce satisfying the difficulty conditions
    def mine(block_number, transactions, previous_hash, prefix_zeros, QC_switch):

        prefix_str = '0'*prefix_zeros #sets the difficulty, in hex format, bin: multiply by 4
        
        start = time.time()
        comp_time_block = 0
        
        for nonce in range(MAX_NONCE):
            text = str(block_number) + transactions + previous_hash + str(nonce) #hash input
            print ('text:', text, '\n'  )
            [new_hash, comp_time] = qPoW(text,QC_switch,nonce)

            #write to log file
            with open(filename_log, 'a') as o:
                o.write('nonce:'+ str(nonce)+'\n')
                o.write('hashOut:'+ str(new_hash)+'\n\n')
            comp_time_block+=comp_time
            
            if new_hash.startswith(prefix_str):
                break

        print(f"qPoW completed. Successfully mined a block with a nonce value:{nonce}")
        with open(filename_log, 'a') as o:
            o.write('qPoW completed. Successfully mined a block with a nonce value' +str(nonce)+'\n')
        with open(filename_results, 'a') as o:
            o.write('qPoW completed.' +str(nonce)+'\n')
        with open(filename_bc, 'a') as o:
            o.write('computational time for mining a block:' +str(comp_time_block)+'\n')
        
        total_time = str((time.time() - start))
        print(f"mining ended. mining time: {total_time} seconds")
        print('final hash:', new_hash)
        print('suitable nonce:', nonce)
        
        return [new_hash, nonce, comp_time]

        raise BaseException(f"Couldn't find correct has after trying {MAX_NONCE} times")

    ### Quantum operations

    # converting hashIn_bin to a bit string to pass thru a quantum processor
    def break_up_4bit_values(hashIn_bin):

        array_4_bit_values = []
        i = 0

        while i < 64 : 
          four_bits = hashIn_bin[2+4*i:2+4*i+4]
          array_4_bit_values.append(four_bits)
          i = i + 1
        print("hashIn binary split into 4bit bins:", array_4_bit_values)
        return array_4_bit_values
    
    # setting the quantum circuit:
    def quantum_circuit(q_par, n_qreg = 4, n_creg = 4, circ_layer = 1):
        qreg_q = QuantumRegister(n_qreg, 'q')
        creg_c = ClassicalRegister(n_creg, 'c')
        circuit = QuantumCircuit(qreg_q, creg_c)

        #circuit 6 modified
        for i in range(circ_layer):
            circuit.rx(q_par[0]*pi/8, qreg_q[0])
            circuit.rx(q_par[1]*pi/8, qreg_q[1])
            circuit.rx(q_par[2]*pi/8, qreg_q[2])
            circuit.rx(q_par[3]*pi/8, qreg_q[3])
            circuit.rz(q_par[4]*pi/2, qreg_q[0])
            circuit.rz(q_par[5]*pi/8, qreg_q[1])
            circuit.rz(q_par[6]*pi/8, qreg_q[2])
            circuit.rz(q_par[7]*pi/8, qreg_q[3])
            circuit.crx(q_par[8]*pi/8, qreg_q[3], qreg_q[2])
            circuit.crx(q_par[9]*pi/8, qreg_q[3], qreg_q[1])
            circuit.crx(q_par[10]*pi/8, qreg_q[3], qreg_q[0])
            circuit.crx(q_par[11]*pi/8, qreg_q[2], qreg_q[3])
            circuit.crx(q_par[12]*pi/8, qreg_q[2], qreg_q[1])
            circuit.crx(q_par[13]*pi/8, qreg_q[2], qreg_q[0])
            circuit.crx(q_par[14]*pi/8, qreg_q[1], qreg_q[3])
            circuit.crx(q_par[15]*pi/8, qreg_q[1], qreg_q[2])
            circuit.crx(q_par[16]*pi/8, qreg_q[1], qreg_q[0])
            circuit.rz(q_par[17]*pi/8, qreg_q[3])
            circuit.rz(q_par[18]*pi/8, qreg_q[2])
            circuit.rz(q_par[19]*pi/8, qreg_q[0])
            circuit.rz(q_par[20]*pi/8, qreg_q[1])
            circuit.crx(q_par[21]*pi/8, qreg_q[0], qreg_q[3])
            circuit.crx(q_par[22]*pi/8, qreg_q[0], qreg_q[2])
            circuit.crx(q_par[23]*pi/8, qreg_q[0], qreg_q[1])
            circuit.rx(q_par[24]*pi/8, qreg_q[3])
            circuit.rx(q_par[25]*pi/8, qreg_q[2])
            circuit.rx(q_par[26]*pi/8, qreg_q[0])
            circuit.rx(q_par[27]*pi/8, qreg_q[1])

        #measurements of all qubits
        for i in range(len(qreg_q)):
            circuit.measure(qreg_q[i], creg_c[i])
        
        return circuit
        
        
    # real(experimental) quantum computor run
    def exp_quantum_operation(quantum_circuit, hashIn, nonce, qpu_backend):

        #input hashIn string
        fourbit_array = break_up_4bit_values(hashIn)
        q_par = [int(fourbit_array[i],2) for i in range(len(fourbit_array)-1)] #throwing away the last string element
        circuit = quantum_circuit(q_par)
        
        #for IBMQ machines the circuit needs to go thru the transpilation (expression in basic gates)
        transpiled_circuit = transpile(circuit, qpu_backend, seed_transpiler=13)

        qpu_job = qpu_backend.run(transpiled_circuit, shots=20000)
        job_id = qpu_job.job_id()
        print("Job id", job_id)

        # Monitor job progress and wait until complete:
        job_monitor(qpu_job)

        # Get the job results (this method also waits for the Job to complete):
        results = qpu_job.result()
        print(results)
        
        with open(filename_log, 'a') as o:
            o.write(str(results) + '\n')

        with open(filename_results, 'a') as o:
            o.write("time taken: {} sec".format(results.time_taken) + '\n')
        
        comp_time = results.time_taken
        
        counts = {format(n, "03b"): 0 for n in range(8)}
        counts.update(results.get_counts(circuit))
        print(counts)

        # plot histograms
        hist_filename = filepath + 'exp_histogram' + job_id
        plot_histogram(counts, filename = hist_filename, figsize=(7, 5))

        #draw the quantum circuit
        drawC_filename = filepath + 'exp_q_circuit' + job_id
        drawTC_filename = filepath + 'exp_q_Tcircuit' + job_id
        circuit.draw('mpl', fold=0, filename = drawC_filename)
        transpiled_circuit.draw('mpl',fold=0, filename = drawTC_filename)

        #picking up the maximally probable state
        max_state = max(counts, key=counts.get)
        max_state256 = max_state

        for i in range(256 - len(max_state)):
            max_state256+='0' 

        with open(filename_results, 'a') as o:
            o.write(str(job_id) + ',' + str(max_state)+',')

        return [max_state256, comp_time] #4bit vector

    # quantum simulator run
    def sim_quantum_operation(hashIn, nonce):

        #input hashIn string
        fourbit_array = break_up_4bit_values(hashIn)
        q_par = [int(fourbit_array[i],2) for i in range(len(fourbit_array)-1)] #throwing away the last string element
        circuit = quantum_circuit(q_par)

        backend = BasicAer.get_backend(simulator_name) # run on local simulator by default 

        job = execute(circuit, backend, shots=20000)

        # Monitor job progress and wait until complete:
        job_monitor(job)

        # Get the job results (this method also waits for the Job to complete):
        results = job.result()
        print(results)

        with open(filename_log, 'a') as o:
            o.write(str(results) + '\n')

        with open(filename_results, 'a') as o:
            o.write("time taken: {} sec".format(results.time_taken) + '\n')
        
        comp_time = results.time_taken
        counts = results.get_counts(circuit)

        #plot histograms
        hist_filename = filepath + 'sim_histogram' + str(nonce)
        plot_histogram(counts, filename = hist_filename, figsize=(7, 7))

        #draw the quantum circuit
        drawC_filename = filepath + 'sim_q_circuit' + str(nonce)
        circuit.draw('mpl', fold=0, filename = drawC_filename)

        #picking up the maximally probable state
        max_state = max(counts, key=counts.get)
        print ('max_state:', max_state)
        max_state256 = max_state

        for i in range(256 - len(max_state)):
            max_state256+='0' 

        with open(filename_results, 'a') as o:
            o.write('max_state = '+str(max_state)+', '+'nonce = '+str(nonce)+', ' + '\n')


        return [max_state256, comp_time] #4bit vector

    def xor(a, b, n): #a,b - strings, n - length of the XOR output
        ans = ""

        # Loop to iterate over the
        # Binary Strings
        for i in range(n):

            # If the Character matches
            if (a[i] == b[i]):
                ans += "0"
            else:
                ans += "1"
        return ans


    ### Execute QPoW
    [new_hash, nonce, comp_time] = mine(block_number,transactions, previous_hash, difficulty, QC_switch)
    
    ### Verify with the quantum simulator

    def verify(nonce, block_number, transactions, previous_hash, prefix_zeros, QC_switch):
        prefix_str = '0'*prefix_zeros

        print('nonce:', nonce)
        text = str(block_number) + transactions + previous_hash + str(nonce)
        print('text:', text)
        [new_hash, ver_time] = qPoW(text,QC_switch, nonce)

        if new_hash.startswith(prefix_str):
            print(f"Verified: nonce {nonce}\n") 
            with open(filename_results, 'a') as o:
                o.write('Verified' + '\n')
            with open(filename_log, 'a') as o:
                o.write('Verified' + '\n')
            return [True, new_hash, ver_time]
        else:
            print(f"False:{nonce}\n")
            with open(filename_results, 'a') as o:
                o.write('False' + '\n')
            with open(filename_log, 'a') as o:
                o.write('False' + '\n')
            return [False, previous_hash, ver_time]
    
    [check, new_hash, ver_time] = verify(nonce, block_number, transactions, previous_hash, difficulty, QC_switch = 0)
    
    if check == True: 
        previous_hash = new_hash
        block_number+= 1
        counter+= 1 
        with open(filename_bc, 'a') as o:
            o.write('block_number:' + str(block_number-1) + '\n')
            o.write('nonce:' + str(nonce)+ '\n')
            o.write('previous_hash:' + str(previous_hash)+ '\n')
            o.write('transactions:' + str(transactions) +'\n')
            o.write('errors:' + str(errors) +'\n')
            o.write('time for verifying a block:' +str(ver_time)+'\n\n')
        
    else:
        previous_hash = previous_hash
        block_number = block_number
        errors += 1
        print('number of errors:', errors)
# Out:
# text: 0Schroedinger paid Einstein 1 qBTC0
#
# hashIn-hex: 0876a34b05a4b00141da5b044fff88fe3e81a92842fb42ba1727078a303e6c67 length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['0010', '0001', '1101', '1010', '1000', '1101', '0010', '1100', '0001', '0110', '1001', '0010', '1100', '0000', '0000', '0101', '0000', '0111', '0110', '1001', '0110', '1100', '0001', '0001', '0011', '1111', '1111', '1110', '0010', '0011', '1111', '1000', '1111', '1010', '0000', '0110', '1010', '0100', '1010', '0001', '0000', '1011', '1110', '1101', '0000', '1010', '1110', '1000', '0101', '1100', '1001', '1100', '0001', '1110', '0010', '1000', '1100', '0000', '1111', '1001', '1011', '0001', '1001', '11']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='2453b41e-98b9-436d-aaed-de855cee6b6e', job_id='bfb3e674-9765-4116-b2fd-20652f8f28ae', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0xf': 7358, '0xb': 1990, '0x4': 2075, '0xd': 2022, '0x6': 1077, '0xa': 173, '0x2': 479, '0x9': 1043, '0x0': 967, '0xc': 747, '0xe': 813, '0x8': 232, '0x5': 442, '0x7': 324, '0x3': 71, '0x1': 187}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=1.767145867644264, memory_slots=4, metadata={}, n_qubits=4, name='circuit-2', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-2', seed_simulator=1556763520, time_taken=0.11068129539489746)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.11068129539489746)
# max_state: 1111
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 9cc81bab890cbe8505d6d27e9ee21d3e5abdcb4d1665432d6f04865f6586ebad length: 64
#
#
# text: 0Schroedinger paid Einstein 1 qBTC1
#
# hashIn-hex: 30dced2146094bcac07eb13a181c29146ee9548d7ccbdbe385f2ca1451c0d7ee length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['1100', '0011', '0111', '0011', '1011', '0100', '1000', '0101', '0001', '1000', '0010', '0101', '0010', '1111', '0010', '1011', '0000', '0001', '1111', '1010', '1100', '0100', '1110', '1000', '0110', '0000', '0111', '0000', '1010', '0100', '0101', '0001', '1011', '1011', '1010', '0101', '0101', '0010', '0011', '0101', '1111', '0011', '0010', '1111', '0110', '1111', '1000', '1110', '0001', '0111', '1100', '1011', '0010', '1000', '0101', '0001', '0100', '0111', '0000', '0011', '0101', '1111', '1011', '10']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='e8660121-a664-4358-829a-9422b1e7c2bf', job_id='ad46a31b-aeee-4ed4-b2b2-70309ad889ca', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0xf': 165, '0x6': 2945, '0x5': 3833, '0x3': 4380, '0x8': 2128, '0xc': 263, '0x2': 1167, '0x7': 1087, '0x9': 605, '0x0': 1714, '0xe': 259, '0xd': 1347, '0x1': 91, '0x4': 5, '0xa': 8, '0xb': 3}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=2.552544031041709, memory_slots=4, metadata={}, n_qubits=4, name='circuit-290', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-290', seed_simulator=1291542162, time_taken=0.12765860557556152)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.12765860557556152)
# max_state: 0011
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 32ade22e2577fa19c47b58669c2f49725cac2782cb6ed50083cc48b643a2b45d length: 64
#
#
# text: 0Schroedinger paid Einstein 1 qBTC2
#
# hashIn-hex: e30aaf3ca114605c163594d623988b474bab8187226d1e74b25fefcefe2e8cf2 length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['1000', '1100', '0010', '1010', '1011', '1100', '1111', '0010', '1000', '0100', '0101', '0001', '1000', '0001', '0111', '0000', '0101', '1000', '1101', '0110', '0101', '0011', '0101', '1000', '1000', '1110', '0110', '0010', '0010', '1101', '0001', '1101', '0010', '1110', '1010', '1110', '0000', '0110', '0001', '1100', '1000', '1001', '1011', '0100', '0111', '1001', '1101', '0010', '1100', '1001', '0111', '1111', '1011', '1111', '0011', '1011', '1111', '1000', '1011', '1010', '0011', '0011', '1100', '10']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='1c496c52-ee89-44f6-8436-e8726a1b2130', job_id='eaf089ce-c5dd-424d-8124-f73791939dad', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x6': 386, '0x1': 4222, '0xc': 1784, '0x4': 1752, '0x5': 1436, '0x9': 698, '0xf': 2377, '0xb': 1736, '0xa': 1185, '0xe': 1167, '0x7': 2215, '0xd': 635, '0x2': 253, '0x3': 85, '0x0': 49, '0x8': 20}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=4.516039439535328, memory_slots=4, metadata={}, n_qubits=4, name='circuit-493', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-493', seed_simulator=830072859, time_taken=0.0857703685760498)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.0857703685760498)
# max_state: 0001
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 935dd84e7b50798b7d21d19c608dea5bff781923c6e420fbe9a7004028d4801d length: 64
#
#
# text: 0Schroedinger paid Einstein 1 qBTC3
#
# hashIn-hex: a27652f2cde1fc0eba58462fc8b31ec25ce237ab3e13c321775f9888076b62cc length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['1000', '1001', '1101', '1001', '0100', '1011', '1100', '1011', '0011', '0111', '1000', '0111', '1111', '0000', '0011', '1010', '1110', '1001', '0110', '0001', '0001', '1000', '1011', '1111', '0010', '0010', '1100', '1100', '0111', '1011', '0000', '1001', '0111', '0011', '1000', '1000', '1101', '1110', '1010', '1100', '1111', '1000', '0100', '1111', '0000', '1100', '1000', '0101', '1101', '1101', '0111', '1110', '0110', '0010', '0010', '0000', '0001', '1101', '1010', '1101', '1000', '1011', '0011', '00']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='6d114ee2-7865-443d-8299-abf402b59560', job_id='eabe083f-3720-469f-bfea-74d111add243', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0xc': 1769, '0x0': 1113, '0x3': 2129, '0x5': 1077, '0xa': 1649, '0x9': 1581, '0xf': 2197, '0x6': 921, '0x4': 349, '0x2': 1853, '0x7': 728, '0xb': 1021, '0xd': 890, '0x8': 734, '0x1': 141, '0xe': 1848}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=2.552544031041709, memory_slots=4, metadata={}, n_qubits=4, name='circuit-700', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-700', seed_simulator=749817119, time_taken=0.10471940040588379)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.10471940040588379)
# max_state: 1111
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: bf6c99b509fe5c13d63c1aa1f17e26cec6bfcd69c58b439cef6f6dbb9672104c length: 64
#
#
# text: 0Schroedinger paid Einstein 1 qBTC4
#
# hashIn-hex: ec8b3d13f4046e72af4a34f4a9a37fb7ac0db390357bd8faa6e7285d67cf1d42 length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['1011', '0010', '0010', '1100', '1111', '0100', '0100', '1111', '1101', '0000', '0001', '0001', '1011', '1001', '1100', '1010', '1011', '1101', '0010', '1000', '1101', '0011', '1101', '0010', '1010', '0110', '1000', '1101', '1111', '1110', '1101', '1110', '1011', '0000', '0011', '0110', '1100', '1110', '0100', '0000', '1101', '0101', '1110', '1111', '0110', '0011', '1110', '1010', '1001', '1011', '1001', '1100', '1010', '0001', '0111', '0101', '1001', '1111', '0011', '1100', '0111', '0101', '0000', '10']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='882c089b-0491-45c2-b49f-1c2c2b9b696f', job_id='78c6ec29-40f2-4e47-a93c-efdd813b8b59', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x1': 1101, '0xf': 2860, '0x2': 943, '0x7': 2080, '0x0': 3949, '0xc': 1569, '0x6': 1825, '0x8': 1655, '0x4': 680, '0xd': 503, '0xb': 585, '0x5': 568, '0xa': 802, '0x9': 411, '0xe': 362, '0x3': 107}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=4.908738521234053, memory_slots=4, metadata={}, n_qubits=4, name='circuit-907', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-907', seed_simulator=1615332568, time_taken=0.09474682807922363)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.09574341773986816)
# max_state: 0000
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: dd6be63eef6e657aa31f9c7a9e0c26bc2c6abf1cc5484788e0a4724a2e011bbf length: 64
#
#
# text: 0Schroedinger paid Einstein 1 qBTC5
#
# hashIn-hex: 4708361f7daca2d71c50512397ce4c9ee2955ccdee6d946148fe16dc6dfdacbb length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['0001', '1100', '0010', '0000', '1101', '1000', '0111', '1101', '1111', '0110', '1011', '0010', '1000', '1011', '0101', '1100', '0111', '0001', '0100', '0001', '0100', '0100', '1000', '1110', '0101', '1111', '0011', '1001', '0011', '0010', '0111', '1011', '1000', '1010', '0101', '0101', '0111', '0011', '0011', '0111', '1011', '1001', '1011', '0110', '0101', '0001', '1000', '0101', '0010', '0011', '1111', '1000', '0101', '1011', '0111', '0001', '1011', '0111', '1111', '0110', '1011', '0010', '1110', '11']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='0778cf98-7d0f-4036-b5fd-e4be92f4335f', job_id='499a80ee-90f7-444f-b902-3fb9cd813c0e', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0xe': 350, '0x5': 3100, '0x1': 2767, '0xa': 3881, '0x4': 1729, '0xd': 808, '0xb': 2082, '0x8': 684, '0x2': 1178, '0xf': 647, '0xc': 116, '0x9': 874, '0x6': 126, '0x3': 1340, '0x0': 285, '0x7': 33}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=4.3196898986859615, memory_slots=4, metadata={}, n_qubits=4, name='circuit-1114', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-1114', seed_simulator=106500196, time_taken=0.1495988368988037)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.15059709548950195)
# max_state: 1010
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 0efb16fed17dd4113a367891121e8cd50fec2f5e804c7c81726aa1d201cee830 length: 64
#
#
# qPoW completed. Successfully mined a block with a nonce value:5
# mining ended. mining time: 7.776369094848633 seconds
# final hash: 0efb16fed17dd4113a367891121e8cd50fec2f5e804c7c81726aa1d201cee830
# suitable nonce: 5
# nonce: 5
# text: 0Schroedinger paid Einstein 1 qBTC5
# hashIn-hex: 4708361f7daca2d71c50512397ce4c9ee2955ccdee6d946148fe16dc6dfdacbb length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['0001', '1100', '0010', '0000', '1101', '1000', '0111', '1101', '1111', '0110', '1011', '0010', '1000', '1011', '0101', '1100', '0111', '0001', '0100', '0001', '0100', '0100', '1000', '1110', '0101', '1111', '0011', '1001', '0011', '0010', '0111', '1011', '1000', '1010', '0101', '0101', '0111', '0011', '0011', '0111', '1011', '1001', '1011', '0110', '0101', '0001', '1000', '0101', '0010', '0011', '1111', '1000', '0101', '1011', '0111', '0001', '1011', '0111', '1111', '0110', '1011', '0010', '1110', '11']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='bf6cf698-d6cc-42b1-839e-ed3c1b05bdf6', job_id='b46f7568-f96b-490a-bfcf-06fa3d8d2a85', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x9': 838, '0x5': 3062, '0xa': 3964, '0x4': 1781, '0xb': 2024, '0x1': 2631, '0x2': 1222, '0xd': 805, '0x3': 1379, '0xe': 376, '0x8': 699, '0xf': 657, '0x6': 161, '0xc': 124, '0x0': 251, '0x7': 26}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=4.3196898986859615, memory_slots=4, metadata={}, n_qubits=4, name='circuit-1331', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-1331', seed_simulator=1679086673, time_taken=0.12566280364990234)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.12566280364990234)
# max_state: 1010
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 0efb16fed17dd4113a367891121e8cd50fec2f5e804c7c81726aa1d201cee830 length: 64
#
#
# Verified: nonce 5
#
# text: 1Schroedinger paid Einstein 1 qBTC0efb16fed17dd4113a367891121e8cd50fec2f5e804c7c81726aa1d201cee8300
#
# hashIn-hex: 4b5911ca2903c6e875f1232adeda27f15df93a9e2879bf4c4e60526cea9fb46b length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['0010', '1101', '0110', '0100', '0100', '0111', '0010', '1000', '1010', '0100', '0000', '1111', '0001', '1011', '1010', '0001', '1101', '0111', '1100', '0100', '1000', '1100', '1010', '1011', '0111', '1011', '0110', '1000', '1001', '1111', '1100', '0101', '0111', '0111', '1110', '0100', '1110', '1010', '0111', '1000', '1010', '0001', '1110', '0110', '1111', '1101', '0011', '0001', '0011', '1001', '1000', '0001', '0100', '1001', '1011', '0011', '1010', '1010', '0111', '1110', '1101', '0001', '1010', '11']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='636181f1-6665-4a95-8249-acc854ecfe60', job_id='eb5d6c4a-d408-4124-bdcf-fcd45461cecd', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 377, '0x1': 1834, '0xd': 4377, '0x9': 4558, '0xb': 2236, '0x8': 608, '0x4': 269, '0xa': 1613, '0x5': 986, '0x3': 726, '0x7': 491, '0x2': 172, '0xe': 391, '0x6': 980, '0xf': 357, '0xc': 25}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=2.805245260586692e-15, memory_slots=4, metadata={}, n_qubits=4, name='circuit-1548', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-1548', seed_simulator=444618661, time_taken=0.12366962432861328)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.12366962432861328)
# max_state: 1001
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 03f679b959503a5656b64aee9eccb63daae4e301791689f21fc4cc6ba8ca012f length: 64
#
#
# qPoW completed. Successfully mined a block with a nonce value:0
# mining ended. mining time: 1.0372247695922852 seconds
# final hash: 03f679b959503a5656b64aee9eccb63daae4e301791689f21fc4cc6ba8ca012f
# suitable nonce: 0
# nonce: 0
# text: 1Schroedinger paid Einstein 1 qBTC0efb16fed17dd4113a367891121e8cd50fec2f5e804c7c81726aa1d201cee8300
# hashIn-hex: 4b5911ca2903c6e875f1232adeda27f15df93a9e2879bf4c4e60526cea9fb46b length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['0010', '1101', '0110', '0100', '0100', '0111', '0010', '1000', '1010', '0100', '0000', '1111', '0001', '1011', '1010', '0001', '1101', '0111', '1100', '0100', '1000', '1100', '1010', '1011', '0111', '1011', '0110', '1000', '1001', '1111', '1100', '0101', '0111', '0111', '1110', '0100', '1110', '1010', '0111', '1000', '1010', '0001', '1110', '0110', '1111', '1101', '0011', '0001', '0011', '1001', '1000', '0001', '0100', '1001', '1011', '0011', '1010', '1010', '0111', '1110', '1101', '0001', '1010', '11']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='21776513-eeca-48f9-98de-b9b5213f9be2', job_id='c531051d-0cab-479a-b23f-0faa418c8f1e', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0xd': 4399, '0xa': 1536, '0x0': 354, '0x9': 4446, '0x1': 1805, '0xf': 334, '0x8': 646, '0x7': 490, '0xb': 2277, '0x6': 1011, '0x5': 1073, '0x3': 738, '0x2': 194, '0x4': 258, '0xe': 404, '0xc': 35}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=2.805245260586692e-15, memory_slots=4, metadata={}, n_qubits=4, name='circuit-1755', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-1755', seed_simulator=838158776, time_taken=0.08978676795959473)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.08978676795959473)
# max_state: 1001
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 03f679b959503a5656b64aee9eccb63daae4e301791689f21fc4cc6ba8ca012f length: 64
#
#
# Verified: nonce 0
#
# text: 2Schroedinger paid Einstein 1 qBTC03f679b959503a5656b64aee9eccb63daae4e301791689f21fc4cc6ba8ca012f0
#
# hashIn-hex: 4b158ee1d5915e178cc73e9843c64031b1cb2025b05311d0a5ec08eb52686606 length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['0010', '1100', '0101', '0110', '0011', '1011', '1000', '0111', '0101', '0110', '0100', '0101', '0111', '1000', '0101', '1110', '0011', '0011', '0001', '1100', '1111', '1010', '0110', '0001', '0000', '1111', '0001', '1001', '0000', '0000', '1100', '0110', '1100', '0111', '0010', '1100', '1000', '0000', '1001', '0110', '1100', '0001', '0100', '1100', '0100', '0111', '0100', '0010', '1001', '0111', '1011', '0000', '0010', '0011', '1010', '1101', '0100', '1001', '1010', '0001', '1001', '1000', '0001', '10']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='4cf6cc94-93f0-40ad-a6f0-a70a7474fb8a', job_id='226b71d4-7491-4b19-8a5d-92d30aaa1565', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0xb': 2159, '0x5': 2061, '0x9': 3986, '0x8': 353, '0x0': 1024, '0xa': 2229, '0x2': 588, '0xd': 1696, '0xc': 990, '0xf': 1301, '0x4': 1064, '0x7': 1579, '0xe': 210, '0x1': 659, '0x6': 68, '0x3': 33}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=2.1598449493429825, memory_slots=4, metadata={}, n_qubits=4, name='circuit-1962', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-1962', seed_simulator=1906282170, time_taken=0.24334716796875)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.24434471130371094)
# max_state: 1001
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: aa9575bc342d438fae32f75f13cd8a2dde9cc9cd27a2a618fa7d064136302dbf length: 64
#
#
# text: 2Schroedinger paid Einstein 1 qBTC03f679b959503a5656b64aee9eccb63daae4e301791689f21fc4cc6ba8ca012f1
#
# hashIn-hex: 825c5bb1ed0cf850e36c46f9c5ed62d2f4d7fc3ed2ecd2b8a5056847ce10105a length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['0000', '1001', '0111', '0001', '0110', '1110', '1100', '0111', '1011', '0100', '0011', '0011', '1110', '0001', '0100', '0011', '1000', '1101', '1011', '0001', '0001', '1011', '1110', '0111', '0001', '0111', '1011', '0101', '1000', '1011', '0100', '1011', '1101', '0011', '0101', '1111', '1111', '0000', '1111', '1011', '0100', '1011', '1011', '0011', '0100', '1010', '1110', '0010', '1001', '0100', '0001', '0101', '1010', '0001', '0001', '1111', '0011', '1000', '0100', '0000', '0100', '0001', '0110', '10']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='23d94bde-5f71-4eeb-9657-308ec64d85f0', job_id='887bd466-3b29-4bf7-aea1-bfaa1f6a6175', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x4': 2180, '0xe': 3153, '0xa': 1288, '0x1': 1119, '0x6': 1478, '0x3': 1925, '0xd': 1565, '0xb': 233, '0x7': 1471, '0xf': 1074, '0xc': 1523, '0x5': 932, '0x9': 810, '0x8': 295, '0x0': 657, '0x2': 297}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=2.552544031041709, memory_slots=4, metadata={}, n_qubits=4, name='circuit-2179', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-2179', seed_simulator=1142239890, time_taken=0.11868166923522949)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.11968040466308594)
# max_state: 1110
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 777f635c766074cecbdaa5e8ac3209253b51bf1ed97c83295648cd6478005f90 length: 64
#
#
# text: 2Schroedinger paid Einstein 1 qBTC03f679b959503a5656b64aee9eccb63daae4e301791689f21fc4cc6ba8ca012f2
#
# hashIn-hex: 83ff335432e8d70a8fe271f0f726eff3e067cc8b105abd2d4471851ca2c0b240 length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['0000', '1111', '1111', '1100', '1100', '1101', '0101', '0000', '1100', '1011', '1010', '0011', '0101', '1100', '0010', '1010', '0011', '1111', '1000', '1001', '1100', '0111', '1100', '0011', '1101', '1100', '1001', '1011', '1011', '1111', '1100', '1111', '1000', '0001', '1001', '1111', '0011', '0010', '0010', '1100', '0100', '0001', '0110', '1010', '1111', '0100', '1011', '0101', '0001', '0001', '1100', '0110', '0001', '0100', '0111', '0010', '1000', '1011', '0000', '0010', '1100', '1001', '0000', '00']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='8c7bffeb-9a88-41e2-908a-f1a2f894e555', job_id='6d737f6f-d916-449f-9bef-8c71cd70aa86', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 3489, '0xf': 1355, '0x3': 5060, '0xc': 629, '0x4': 591, '0x7': 2210, '0xe': 363, '0x2': 426, '0xd': 517, '0x9': 2182, '0xb': 345, '0x5': 924, '0x6': 1372, '0x1': 475, '0x8': 24, '0xa': 38}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=0.39269908169872636, memory_slots=4, metadata={}, n_qubits=4, name='circuit-2396', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-2396', seed_simulator=395731220, time_taken=0.09175324440002441)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.09275054931640625)
# max_state: 0011
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 9dc9335b3bf7012ba1caafc7c22982b9d08ba13e84757e0cf0598eb5bc107965 length: 64
#
#
# text: 2Schroedinger paid Einstein 1 qBTC03f679b959503a5656b64aee9eccb63daae4e301791689f21fc4cc6ba8ca012f3
#
# hashIn-hex: f3b8c110c6f788c260101ea14c9f23fb521a421a3ab09880007645478e98513e length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['1100', '1110', '1110', '0011', '0000', '0100', '0100', '0011', '0001', '1011', '1101', '1110', '0010', '0011', '0000', '1001', '1000', '0000', '0100', '0000', '0111', '1010', '1000', '0101', '0011', '0010', '0111', '1100', '1000', '1111', '1110', '1101', '0100', '1000', '0110', '1001', '0000', '1000', '0110', '1000', '1110', '1010', '1100', '0010', '0110', '0010', '0000', '0000', '0000', '0001', '1101', '1001', '0001', '0101', '0001', '1110', '0011', '1010', '0110', '0001', '0100', '0100', '1111', '10']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='300fa6b1-c371-4642-8c3b-c7ae944752fe', job_id='10c55375-cc19-45b5-b5b3-a4c33f99102d', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x4': 6453, '0x1': 1704, '0x9': 2728, '0xf': 2221, '0x2': 409, '0x3': 2487, '0xd': 1133, '0x7': 110, '0x6': 364, '0x0': 792, '0xb': 576, '0xc': 532, '0xe': 247, '0x5': 115, '0x8': 95, '0xa': 34}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=1.9634954084936251, memory_slots=4, metadata={}, n_qubits=4, name='circuit-2609', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-2609', seed_simulator=849066833, time_taken=0.10870909690856934)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.10970640182495117)
# max_state: 0100
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 253b277024363692a322e572daf3562350b2ce6fc29e769606863ad2b41237c1 length: 64
#
#
# text: 2Schroedinger paid Einstein 1 qBTC03f679b959503a5656b64aee9eccb63daae4e301791689f21fc4cc6ba8ca012f4
#
# hashIn-hex: 3e1b4bda6a6595c011c047ddc9716fb60ddeee2a1db19c5bab1656a40c2a9cd3 length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['1111', '1000', '0110', '1101', '0010', '1111', '0110', '1001', '1010', '1001', '1001', '0110', '0101', '0111', '0000', '0000', '0100', '0111', '0000', '0001', '0001', '1111', '0111', '0111', '0010', '0101', '1100', '0101', '1011', '1110', '1101', '1000', '0011', '0111', '0111', '1011', '1011', '1000', '1010', '1000', '0111', '0110', '1100', '0110', '0111', '0001', '0110', '1110', '1010', '1100', '0101', '1001', '0101', '1010', '1001', '0000', '0011', '0000', '1010', '1010', '0111', '0011', '0100', '11']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='406596ad-1d7d-4c9c-9531-ecf2fdaf447b', job_id='d1b78fcf-a5a3-420e-95fb-1effa12366ce', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0xe': 6256, '0x7': 1278, '0xc': 2077, '0x6': 2510, '0xf': 864, '0xd': 971, '0x8': 564, '0x9': 309, '0x3': 317, '0xb': 980, '0x1': 473, '0x5': 1190, '0xa': 329, '0x2': 844, '0x4': 932, '0x0': 106}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=3.337942194439158, memory_slots=4, metadata={}, n_qubits=4, name='circuit-2816', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-2816', seed_simulator=1172617843, time_taken=0.09873628616333008)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.09973359107971191)
# max_state: 1110
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 0bc6eef5b813c0e6646d059373f34d8514c1a2853ae2bdecd60bc6c5232caef4 length: 64
#
#
# qPoW completed. Successfully mined a block with a nonce value:4
# mining ended. mining time: 5.209061622619629 seconds
# final hash: 0bc6eef5b813c0e6646d059373f34d8514c1a2853ae2bdecd60bc6c5232caef4
# suitable nonce: 4
# nonce: 4
# text: 2Schroedinger paid Einstein 1 qBTC03f679b959503a5656b64aee9eccb63daae4e301791689f21fc4cc6ba8ca012f4
# hashIn-hex: 3e1b4bda6a6595c011c047ddc9716fb60ddeee2a1db19c5bab1656a40c2a9cd3 length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['1111', '1000', '0110', '1101', '0010', '1111', '0110', '1001', '1010', '1001', '1001', '0110', '0101', '0111', '0000', '0000', '0100', '0111', '0000', '0001', '0001', '1111', '0111', '0111', '0010', '0101', '1100', '0101', '1011', '1110', '1101', '1000', '0011', '0111', '0111', '1011', '1011', '1000', '1010', '1000', '0111', '0110', '1100', '0110', '0111', '0001', '0110', '1110', '1010', '1100', '0101', '1001', '0101', '1010', '1001', '0000', '0011', '0000', '1010', '1010', '0111', '0011', '0100', '11']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='f00d156e-c6fd-4d87-a40d-740e9d0b7bf3', job_id='2934fdbe-691f-4462-9b7a-9b489c4c94d5', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x5': 1157, '0xe': 6172, '0x7': 1370, '0xc': 2067, '0x6': 2471, '0x4': 982, '0x2': 884, '0xb': 1035, '0xa': 283, '0xf': 870, '0xd': 981, '0x8': 527, '0x3': 329, '0x1': 479, '0x9': 274, '0x0': 119}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=3.337942194439158, memory_slots=4, metadata={}, n_qubits=4, name='circuit-3013', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-3013', seed_simulator=935089094, time_taken=0.11469078063964844)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.11469078063964844)
# max_state: 1110
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 0bc6eef5b813c0e6646d059373f34d8514c1a2853ae2bdecd60bc6c5232caef4 length: 64
#
#
# Verified: nonce 4
#
# text: 3Schroedinger paid Einstein 1 qBTC0bc6eef5b813c0e6646d059373f34d8514c1a2853ae2bdecd60bc6c5232caef40
#
# hashIn-hex: 8236b06746c370825ad8b052906f0651b858a4240f159b8005376fdb8ddce83e length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['0000', '1000', '1101', '1010', '1100', '0001', '1001', '1101', '0001', '1011', '0000', '1101', '1100', '0010', '0000', '1001', '0110', '1011', '0110', '0010', '1100', '0001', '0100', '1010', '0100', '0001', '1011', '1100', '0001', '1001', '0100', '0110', '1110', '0001', '0110', '0010', '1001', '0000', '1001', '0000', '0011', '1100', '0101', '0110', '0110', '1110', '0000', '0000', '0001', '0100', '1101', '1101', '1011', '1111', '0110', '1110', '0011', '0111', '0111', '0011', '1010', '0000', '1111', '10']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='8a487374-bbe3-4667-971e-4be6f6e38332', job_id='17c2bcdc-0b76-496a-bf26-d5e910be63c0', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x7': 2889, '0x5': 4747, '0x3': 3221, '0x1': 1843, '0x8': 112, '0xc': 566, '0x9': 1976, '0xb': 1505, '0x4': 130, '0x0': 2048, '0xa': 432, '0x2': 126, '0xe': 208, '0x6': 53, '0xf': 123, '0xd': 21}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=5.105088062083414, memory_slots=4, metadata={}, n_qubits=4, name='circuit-3210', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-3210', seed_simulator=1910402037, time_taken=0.10671424865722656)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.1077113151550293)
# max_state: 0101
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: a39e34eee7994dfcfc3fc21cf1695cb2696e9c9c7fe0047b975437760fb92711 length: 64
#
#
# text: 3Schroedinger paid Einstein 1 qBTC0bc6eef5b813c0e6646d059373f34d8514c1a2853ae2bdecd60bc6c5232caef41
#
# hashIn-hex: 853a630f24be737ffbec1e025fc597a06d90f71a81e88b490925fea988d39c02 length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['0001', '0100', '1110', '1001', '1000', '1100', '0011', '1100', '1001', '0010', '1111', '1001', '1100', '1101', '1111', '1111', '1110', '1111', '1011', '0000', '0111', '1000', '0000', '1001', '0111', '1111', '0001', '0110', '0101', '1110', '1000', '0001', '1011', '0110', '0100', '0011', '1101', '1100', '0110', '1010', '0000', '0111', '1010', '0010', '0010', '1101', '0010', '0100', '0010', '0100', '1001', '0111', '1111', '1010', '1010', '0110', '0010', '0011', '0100', '1110', '0111', '0000', '0000', '10']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='49ceefd6-db6b-4c73-ab68-fb2aea5af689', job_id='110b34cf-0a53-4a4a-a3b5-fa146c29da6a', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 648, '0xc': 2977, '0xa': 1395, '0x7': 5311, '0x5': 1836, '0x4': 563, '0xe': 4055, '0x3': 459, '0x2': 688, '0x8': 1290, '0xf': 310, '0x6': 220, '0x1': 72, '0xd': 76, '0x9': 46, '0xb': 54}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=2.4773311031853193, memory_slots=4, metadata={}, n_qubits=4, name='circuit-3403', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-3403', seed_simulator=74770377, time_taken=0.11469340324401855)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.11469340324401855)
# max_state: 0111
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 4662262a3a170daed912f47694e06814c2533c7e8aea48bb77b38cad37f0e5a9 length: 64
#
#
# text: 3Schroedinger paid Einstein 1 qBTC0bc6eef5b813c0e6646d059373f34d8514c1a2853ae2bdecd60bc6c5232caef42
#
# hashIn-hex: 203ec752a27c9ae896da6c994836d8f5ee6b9653ba32fe8506d0b09c2ea385bf length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['1000', '0000', '1111', '1011', '0001', '1101', '0100', '1010', '1000', '1001', '1111', '0010', '0110', '1011', '1010', '0010', '0101', '1011', '0110', '1001', '1011', '0010', '0110', '0101', '0010', '0000', '1101', '1011', '0110', '0011', '1101', '0111', '1011', '1001', '1010', '1110', '0101', '1001', '0100', '1110', '1110', '1000', '1100', '1011', '1111', '1010', '0001', '0100', '0001', '1011', '0100', '0010', '1100', '0010', '0111', '0000', '1011', '1010', '1000', '1110', '0001', '0110', '1111', '11']
# Job Status: job has successfully run
# ...
# hashIn binary split into 4bit bins: ['0101', '0110', '1000', '0011', '0001', '0111', '0010', '1100', '1001', '0010', '0100', '1110', '1001', '1010', '0100', '1101', '0101', '0001', '0001', '1011', '0110', '0001', '0000', '1010', '1100', '0011', '1000', '0110', '0101', '0011', '0000', '1110', '0010', '1100', '1100', '1101', '0110', '0101', '1110', '1100', '1111', '0101', '1101', '0001', '1000', '0110', '1100', '0111', '0110', '0111', '0110', '1100', '0011', '1110', '1110', '0111', '1111', '1110', '1000', '0110', '1101', '0011', '0101', '00']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='0e9356d5-d147-4e7f-bf83-7f234986b08f', job_id='93f421e1-2712-4231-967d-9dd97e04089f', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x5': 836, '0x9': 1029, '0x6': 2308, '0x7': 2095, '0x8': 2740, '0xb': 4527, '0x4': 1692, '0xa': 870, '0xd': 1043, '0x2': 276, '0xf': 1444, '0xc': 472, '0x1': 211, '0xe': 374, '0x0': 28, '0x3': 55}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=1.4688654421463334, memory_slots=4, metadata={}, n_qubits=4, name='circuit-4044', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-4044', seed_simulator=1847799239, time_taken=0.31914544105529785)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.3201432228088379)
# max_state: 1011
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 60c1e88ccfc2e55a9da0b2814fdffd886234333138908c85dc3d56cc26b09e63 length: 64
#
#
# text: 4Schroedinger paid Einstein 1 qBTC04ca1a782621a440d03b5d87ecff8b68e2cc6124f57957b49a76bca91dede3a81
#
# hashIn-hex: e1e5575da3a9e86da135552facddcc1ff44dd26502d0bc2b22961383f8b187ca length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['1000', '0111', '1001', '0101', '0101', '1101', '0111', '0110', '1000', '1110', '1010', '0111', '1010', '0001', '1011', '0110', '1000', '0100', '1101', '0101', '0101', '0100', '1011', '1110', '1011', '0011', '0111', '0111', '0011', '0000', '0111', '1111', '1101', '0001', '0011', '0111', '0100', '1001', '1001', '0100', '0000', '1011', '0100', '0010', '1111', '0000', '1010', '1100', '1000', '1010', '0101', '1000', '0100', '1110', '0000', '1111', '1110', '0010', '1100', '0110', '0001', '1111', '0010', '10']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='7f1de133-debd-456b-b18b-30e314b7d053', job_id='c4361523-fb50-41b6-8ec8-a74d67bb59a6', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x7': 1331, '0x3': 446, '0x6': 3303, '0x0': 1707, '0x5': 323, '0xe': 5028, '0x8': 1376, '0x1': 246, '0x2': 900, '0x4': 2006, '0xb': 518, '0xd': 360, '0x9': 525, '0xf': 504, '0xc': 1386, '0xa': 41}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=4.5160394395353265, memory_slots=4, metadata={}, n_qubits=4, name='circuit-4251', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-4251', seed_simulator=1638743905, time_taken=0.1356368064880371)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.1356368064880371)
# max_state: 1110
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: f307b3db12a649563831e3e1328c3c7a5b15ee541afaab563727cb992cf9d1ca length: 64
#
#
# text: 4Schroedinger paid Einstein 1 qBTC04ca1a782621a440d03b5d87ecff8b68e2cc6124f57957b49a76bca91dede3a82
#
# hashIn-hex: 6b2cddcab66c74806b80a7249b5570b1ee3a2092639954161ed3493dd0b51119 length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['1010', '1100', '1011', '0011', '0111', '0111', '0010', '1010', '1101', '1001', '1011', '0001', '1101', '0010', '0000', '0001', '1010', '1110', '0000', '0010', '1001', '1100', '1001', '0010', '0110', '1101', '0101', '0101', '1100', '0010', '1100', '0111', '1011', '1000', '1110', '1000', '1000', '0010', '0100', '1001', '1000', '1110', '0110', '0101', '0101', '0000', '0101', '1000', '0111', '1011', '0100', '1101', '0010', '0100', '1111', '0111', '0100', '0010', '1101', '0100', '0100', '0100', '0110', '01']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='dd856a33-1468-40b4-9b33-37d916589d86', job_id='74d7c782-0980-4cd9-aac8-c715760ba9fa', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0xb': 783, '0x9': 1592, '0x6': 3500, '0xe': 809, '0x5': 1612, '0x0': 755, '0x4': 1312, '0xa': 4304, '0x2': 763, '0x1': 531, '0xd': 84, '0xf': 2391, '0x3': 1280, '0x7': 232, '0x8': 10, '0xc': 42}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=1.5707963267949017, memory_slots=4, metadata={}, n_qubits=4, name='circuit-4468', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-4468', seed_simulator=499395674, time_taken=0.08679008483886719)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.08776521682739258)
# max_state: 1010
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 1aca7464376caa907dc679bb06243c337f2fe9f536c1d9de07db84d2dcb3b077 length: 64
#
#
# text: 4Schroedinger paid Einstein 1 qBTC04ca1a782621a440d03b5d87ecff8b68e2cc6124f57957b49a76bca91dede3a83
#
# hashIn-hex: 569c9f7525c6a0b6f367a751349ace4c4269603a1388d0aa85ae42c9e0d1db4c length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['0101', '1010', '0111', '0010', '0111', '1101', '1101', '0100', '1001', '0111', '0001', '1010', '1000', '0010', '1101', '1011', '1100', '1101', '1001', '1110', '1001', '1101', '0100', '0100', '1101', '0010', '0110', '1011', '0011', '1001', '0011', '0001', '0000', '1001', '1010', '0101', '1000', '0000', '1110', '1000', '0100', '1110', '0010', '0011', '0100', '0010', '1010', '1010', '0001', '0110', '1011', '1001', '0000', '1011', '0010', '0111', '1000', '0011', '0100', '0111', '0110', '1101', '0011', '00']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='3e464586-5512-4a09-9f6e-ca1bd8456ede', job_id='a53e1be9-86d5-4907-8833-64285efd5645', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 3162, '0x2': 708, '0xa': 155, '0x5': 852, '0x7': 1701, '0x1': 1492, '0x4': 1453, '0x6': 1829, '0xf': 2962, '0xd': 1176, '0x3': 652, '0xc': 569, '0x9': 1226, '0x8': 1768, '0xe': 246, '0xb': 49}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=1.7671458676442646, memory_slots=4, metadata={}, n_qubits=4, name='circuit-4675', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-4675', seed_simulator=363140047, time_taken=0.11269903182983398)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.11269903182983398)
# max_state: 0000
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: f601bc6124f4b50a4dfd3f77d5feb5e879e39dc9da474066d696064978e361a4 length: 64
#
#
# text: 4Schroedinger paid Einstein 1 qBTC04ca1a782621a440d03b5d87ecff8b68e2cc6124f57957b49a76bca91dede3a84
#
# hashIn-hex: e5ceeb7843881efced9a08602053443a640f00a6512f390015845ad12e093d28 length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['1001', '0111', '0011', '1011', '1010', '1101', '1110', '0001', '0000', '1110', '0010', '0000', '0111', '1011', '1111', '0011', '1011', '0110', '0110', '1000', '0010', '0001', '1000', '0000', '1000', '0001', '0100', '1101', '0001', '0000', '1110', '1001', '1001', '0000', '0011', '1100', '0000', '0010', '1001', '1001', '0100', '0100', '1011', '1100', '1110', '0100', '0000', '0000', '0101', '0110', '0001', '0001', '0110', '1011', '0100', '0100', '1011', '1000', '0010', '0100', '1111', '0100', '1010', '00']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='59c96e9b-1cb4-425c-b704-5c851aa13fd7', job_id='3d4e7291-27fe-4a92-9958-5cfcc2701f83', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0xc': 1493, '0x2': 3637, '0x9': 1209, '0xd': 670, '0xb': 765, '0x5': 1103, '0x4': 2584, '0xa': 3651, '0xf': 914, '0x8': 786, '0x0': 484, '0x7': 863, '0x6': 150, '0x1': 1215, '0x3': 468, '0xe': 8}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=1.1780972450961773, memory_slots=4, metadata={}, n_qubits=4, name='circuit-4892', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-4892', seed_simulator=984087730, time_taken=0.0857686996459961)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.0857686996459961)
# max_state: 1010
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 05d7d25556498eabe9e6a238b4f1661afc6763a3f2394df40dacb89ff118765f length: 64
#
#
# qPoW completed. Successfully mined a block with a nonce value:4
# mining ended. mining time: 6.071754217147827 seconds
# final hash: 05d7d25556498eabe9e6a238b4f1661afc6763a3f2394df40dacb89ff118765f
# suitable nonce: 4
# nonce: 4
# text: 4Schroedinger paid Einstein 1 qBTC04ca1a782621a440d03b5d87ecff8b68e2cc6124f57957b49a76bca91dede3a84
# hashIn-hex: e5ceeb7843881efced9a08602053443a640f00a6512f390015845ad12e093d28 length: 64
# hashIn-binary:  length: 256
# hashIn binary split into 4bit bins: ['1001', '0111', '0011', '1011', '1010', '1101', '1110', '0001', '0000', '1110', '0010', '0000', '0111', '1011', '1111', '0011', '1011', '0110', '0110', '1000', '0010', '0001', '1000', '0000', '1000', '0001', '0100', '1101', '0001', '0000', '1110', '1001', '1001', '0000', '0011', '1100', '0000', '0010', '1001', '1001', '0100', '0100', '1011', '1100', '1110', '0100', '0000', '0000', '0101', '0110', '0001', '0001', '0110', '1011', '0100', '0100', '1011', '1000', '0010', '0100', '1111', '0100', '1010', '00']
# Job Status: job has successfully run
# Result(backend_name='qasm_simulator', backend_version='2.1.0', qobj_id='3df4523f-bac3-43e4-9f59-6e6b819e9b2f', job_id='3c14287f-8231-492e-ad13-3d4dfbc4d193', success=True, results=[ExperimentResult(shots=20000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x2': 3587, '0x7': 905, '0xa': 3641, '0x4': 2625, '0x5': 1020, '0x8': 719, '0xb': 816, '0xc': 1493, '0x3': 457, '0x1': 1267, '0x0': 501, '0x9': 1284, '0xd': 623, '0xf': 921, '0x6': 126, '0xe': 15}), header=QobjExperimentHeader(clbit_labels=[['c', 0], ['c', 1], ['c', 2], ['c', 3]], creg_sizes=[['c', 4]], global_phase=1.1780972450961773, memory_slots=4, metadata={}, n_qubits=4, name='circuit-5079', qreg_sizes=[['q', 4]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3]]), status=DONE, name='circuit-5079', seed_simulator=1429012802, time_taken=0.10870862007141113)], status=COMPLETED, status=QobjHeader(backend_name='qasm_simulator', backend_version='2.1.0'), time_taken=0.10970640182495117)
# max_state: 1010
# qblock-output:  length: 256
# XOR:  length: 256
# hashOut-hex: 05d7d25556498eabe9e6a238b4f1661afc6763a3f2394df40dacb89ff118765f length: 64
#
#
# Verified: nonce 4
